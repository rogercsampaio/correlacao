# %% [markdown]
# # Correlação

# %% [markdown]
# ## Importando os pacotes necessários

# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# ### Carregando a base de dados

# %%
pokemons = pd.read_csv('bases/Pokemon.csv')

# %% [markdown]
# <h2> <center> Exemplo </center> </h2> <img src="images/charmander1.PNG" width="500" height="600">

# %%
pokemons.head(5)
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
# Visualizando a quantidade de linhas e colunas
pokemons.shape
# Out:
# (800, 13)

# %% [markdown]
# ## Calculando a correlação (coeficiente)

# %%
# Correlação de todas as variaveis
# Função: DataFrame.corr
pokemons.corr()
# Out:
#                    #     Total        HP    Attack   Defense   Sp. Atk  \
# #           1.000000  0.119813  0.097614  0.102298  0.094786  0.088759
# Total       0.119813  1.000000  0.618748  0.736211  0.612787  0.747250
# HP          0.097614  0.618748  1.000000  0.422386  0.239622  0.362380
# Attack      0.102298  0.736211  0.422386  1.000000  0.438687  0.396362
# Defense     0.094786  0.612787  0.239622  0.438687  1.000000  0.223549
# Sp. Atk     0.088759  0.747250  0.362380  0.396362  0.223549  1.000000
# Sp. Def     0.085817  0.717609  0.378718  0.263990  0.510747  0.506121
# Speed       0.010733  0.575943  0.175952  0.381240  0.015227  0.473018
# Generation  0.982516  0.048384  0.058683  0.051451  0.042419  0.036437
# Legendary   0.153396  0.501758  0.273620  0.345408  0.246377  0.448907
#
#              Sp. Def     Speed  Generation  Legendary
# #           0.085817  0.010733    0.982516   0.153396
# Total       0.717609  0.575943    0.048384   0.501758
# HP          0.378718  0.175952    0.058683   0.273620
# Attack      0.263990  0.381240    0.051451   0.345408
# Defense     0.510747  0.015227    0.042419   0.246377
# Sp. Atk     0.506121  0.473018    0.036437   0.448907
# Sp. Def     1.000000  0.259133    0.028486   0.363937
# Speed       0.259133  1.000000   -0.023121   0.326715
# Generation  0.028486 -0.023121    1.000000   0.079794
# Legendary   0.363937  0.326715    0.079794   1.000000

# %%
# Correlação de apenas algumas.
pokemons.loc[:,['Attack','Total']].corr()
# Out:
#           Attack     Total
# Attack  1.000000  0.736211
# Total   0.736211  1.000000

# %%
# Correlação de apenas algumas.
pokemons.loc[:,['HP','Speed']].corr()
# Out:
#              HP     Speed
# HP     1.000000  0.175952
# Speed  0.175952  1.000000

# %%
# Indica que quanto maior o total, maior sera a defesa. Correlacao positiva
pokemons.loc[:,['Total','Defense']].corr()
# Out:
#             Total   Defense
# Total    1.000000  0.612787
# Defense  0.612787  1.000000

# %%
# Gráfico de calor para visualizar melhor
corr = pokemons.corr()
sns.heatmap(corr, 
        xticklabels=corr.columns,
        yticklabels=corr.columns)

# %%
# Visualizando de outra maneira diferente
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_be6e763c_1446_11ec_b205_616d425dcd29row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_be6e763c_1446_11ec_b205_616d425dcd29row0_col1 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_be6e763c_1446_11ec_b205_616d425dcd29row0_col2 {
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }    #T_be6e763c_1446_11ec_b205_616d425dcd29row0_col3 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_be6e763c_1446_11ec_b205_616d425dcd29row0_col4 {
#             background-color:  #536edd;
#             color:  #000000;
#         }    #T_be6e763c_1446_11ec_b205_616d425dcd29row0_col5 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_be6e763c_1446_11ec_b205_616d425dcd29row0_col6 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_be6e763c_1446_11ec_b205_616d425dcd29row0_col7 {
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }    #T_be6e763c_1446_11ec_b205_616d425dcd29row0_col8 {
#             background-color:  #ba162b;
#             color:  #f1f1f1;
#         }    #T_be6e763c_1446_11ec_b205_616d425dcd29row0_col9 {
#             background-color:  #536edd;
#             color:  #000000;
#         }    #T_be6e763c_1446_11ec_b205_616d425dcd29row1_col0 {
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }    #T_be6e763c_1446_11ec_b205_616d425dcd29row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_be6e763c_1446_11ec_b205_616d425dcd29row1_col2 {
#             background-color:  #f1ccb8;
#             color:  #000000;
#         }    #T_be6e763c_1446_11ec_b205_616d425dcd29row1_col3 {
#             background-color:  #f6a586;
#             color:  #000000;
#         }    #T_be6e763c_1446_11ec_b205_616d425dcd29row1_col4 {
#             background-color:  #f2c9b4;
#             color:  #000000;
#         }    #T_be6e763c_1446_11ec_b205_616d425dcd29row1_col5 {
#             background-color:  #f59f80;
#             color:  #000000;
#         }    #T_be6e763c_1446_11ec_b205_616d425dcd29row1_col6 {
#             background-color:  #f7a98b;
#             color:  #000000;
#         }    #T_be6e763c_1446_11ec_b205_616d425dcd29row1_col7 {
#             background-color:  #efcebd;
#             color:  #000000;
#         }    #T_be6e763c_1446_11ec_b205_616d425dcd29row1_col8 {
#             background-color:  #4f69d9;
#             color:  #000000;
#         }    #T_be6e763c_1446_11ec_b205_616d425dcd29row1_col9 {
#             background-color:  #d2dbe8;
#             color:  #000000;
#         }    #T_be6e763c_1446_11ec_b205_616d425dcd29row2_col0 {
#             background-color:  #5572df;
#             color:  #000000;
#         }    #T_be6e763c_1446_11ec_b205_616d425dcd29row2_col1 {
#             background-color:  #f2cbb7;
#             color:  #000000;
#         }    #T_be6e763c_1446_11ec_b205_616d425dcd29row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_be6e763c_1446_11ec_b205_616d425dcd29row2_col3 {
#             background-color:  #bed2f6;
#             color:  #000000;
#         }    #T_be6e763c_1446_11ec_b205_616d425dcd29row2_col4 {
#             background-color:  #85a8fc;
#             color:  #000000;
#         }    #T_be6e763c_1446_11ec_b205_616d425dcd29row2_col5 {
#             background-color:  #abc8fd;
#             color:  #000000;
#         }    #T_be6e763c_1446_11ec_b205_616d425dcd29row2_col6 {
#             background-color:  #b3cdfb;
#             color:  #000000;
#         }    #T_be6e763c_1446_11ec_b205_616d425dcd29row2_col7 {
#             background-color:  #799cf8;
#             color:  #000000;
#         }    #T_be6e763c_1446_11ec_b205_616d425dcd29row2_col8 {
#             background-color:  #536edd;
#             color:  #000000;
#         }    #T_be6e763c_1446_11ec_b205_616d425dcd29row2_col9 {
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }    #T_be6e763c_1446_11ec_b205_616d425dcd29row3_col0 {
#             background-color:  #5673e0;
#             color:  #000000;
#         }    #T_be6e763c_1446_11ec_b205_616d425dcd29row3_col1 {
#             background-color:  #f6a385;
#             color:  #000000;
#         }    #T_be6e763c_1446_11ec_b205_616d425dcd29row3_col2 {
#             background-color:  #bbd1f8;
#             color:  #000000;
#         }    #T_be6e763c_1446_11ec_b205_616d425dcd29row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_be6e763c_1446_11ec_b205_616d425dcd29row3_col4 {
#             background-color:  #cad8ef;
#             color:  #000000;
#         }    #T_be6e763c_1446_11ec_b205_616d425dcd29row3_col5 {
#             background-color:  #b7cff9;
#             color:  #000000;
#         }    #T_be6e763c_1446_11ec_b205_616d425dcd29row3_col6 {
#             background-color:  #8badfd;
#             color:  #000000;
#         }    #T_be6e763c_1446_11ec_b205_616d425dcd29row3_col7 {
#             background-color:  #bfd3f6;
#             color:  #000000;
#         }    #T_be6e763c_1446_11ec_b205_616d425dcd29row3_col8 {
#             background-color:  #506bda;
#             color:  #000000;
#         }    #T_be6e763c_1446_11ec_b205_616d425dcd29row3_col9 {
#             background-color:  #9abbff;
#             color:  #000000;
#         }    #T_be6e763c_1446_11ec_b205_616d425dcd29row4_col0 {
#             background-color:  #5470de;
#             color:  #000000;
#         }    #T_be6e763c_1446_11ec_b205_616d425dcd29row4_col1 {
#             background-color:  #f1cdba;
#             color:  #000000;
#         }    #T_be6e763c_1446_11ec_b205_616d425dcd29row4_col2 {
#             background-color:  #799cf8;
#             color:  #000000;
#         }    #T_be6e763c_1446_11ec_b205_616d425dcd29row4_col3 {
#             background-color:  #c3d5f4;
#             color:  #000000;
#         }    #T_be6e763c_1446_11ec_b205_616d425dcd29row4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_be6e763c_1446_11ec_b205_616d425dcd29row4_col5 {
#             background-color:  #799cf8;
#             color:  #000000;
#         }    #T_be6e763c_1446_11ec_b205_616d425dcd29row4_col6 {
#             background-color:  #dcdddd;
#             color:  #000000;
#         }    #T_be6e763c_1446_11ec_b205_616d425dcd29row4_col7 {
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }    #T_be6e763c_1446_11ec_b205_616d425dcd29row4_col8 {
#             background-color:  #4e68d8;
#             color:  #000000;
#         }    #T_be6e763c_1446_11ec_b205_616d425dcd29row4_col9 {
#             background-color:  #7597f6;
#             color:  #000000;
#         }    #T_be6e763c_1446_11ec_b205_616d425dcd29row5_col0 {
#             background-color:  #536edd;
#             color:  #000000;
#         }    #T_be6e763c_1446_11ec_b205_616d425dcd29row5_col1 {
#             background-color:  #f59f80;
#             color:  #000000;
#         }    #T_be6e763c_1446_11ec_b205_616d425dcd29row5_col2 {
#             background-color:  #a6c4fe;
#             color:  #000000;
#         }    #T_be6e763c_1446_11ec_b205_616d425dcd29row5_col3 {
#             background-color:  #b5cdfa;
#             color:  #000000;
#         }    #T_be6e763c_1446_11ec_b205_616d425dcd29row5_col4 {
#             background-color:  #80a3fa;
#             color:  #000000;
#         }    #T_be6e763c_1446_11ec_b205_616d425dcd29row5_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_be6e763c_1446_11ec_b205_616d425dcd29row5_col6 {
#             background-color:  #dadce0;
#             color:  #000000;
#         }    #T_be6e763c_1446_11ec_b205_616d425dcd29row5_col7 {
#             background-color:  #d9dce1;
#             color:  #000000;
#         }    #T_be6e763c_1446_11ec_b205_616d425dcd29row5_col8 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }    #T_be6e763c_1446_11ec_b205_616d425dcd29row5_col9 {
#             background-color:  #c0d4f5;
#             color:  #000000;
